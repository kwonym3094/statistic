# %%
# pip install stemgraphic
x = [32, 34, 35, 41, 44, 46, 47, 52, 52, 53, 56, 61, 60, 58, 62,31,75]
import stemgraphic

#create stem-and-leaf plot
fig, ax = stemgraphic.stem_graphic(x)

# %%
# Out:
# 14825600
